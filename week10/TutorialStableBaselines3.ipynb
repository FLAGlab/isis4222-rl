# %% [markdown]
# # Introducción a Stable-Baselines3
#
#
# Stable-Baselines3 (SB3) es una librería basada en PyTorch que contiene la implementación de múltiples algoritmos de Aprendizaje por Refuerzo, una de las librerías mejor actualizadas y documentadas en el campo de Aprendizaje por Refuerzo debido a su naturaleza open-source. Esta librería ofrece implementaciones limpias de diferentes algoritmos como PPO, A2C, SAC, DQN, entre otros, que son fáciles de utilizar con entornos de Gymnasium.
#
# En este notebook se presenta una traducción directa del tutorial oficial de Stable Baselines <a href="https://colab.research.google.com/github/araffin/rl-tutorial-jnrr19/blob/sb3/1_getting_started.ipynb"> <img src="https://colab.research.google.com/assets/colab-badge.svg" width="140" align="center"/> Stable Baselines3 Tutorial - Getting Started</a>. Se sugiere revisar otros tutoriales oficiales que pueden ser encontrados en <a href="https://github.com/araffin/rl-tutorial-jnrr19">este repositorio de GitHub</a>

# %% [markdown]
# # Tutorial de Stable Baselines3 - Primeros Pasos
#
# Repositorio de tutoriales en Github: https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3/
#
# Repositorio oficial de Stable-Baselines3: https://github.com/DLR-RM/stable-baselines3
#
# Documentación oficial de Stable-Baselines3: https://stable-baselines3.readthedocs.io/en/master/
#
# Otras contribuciones de SB3: https://github.com/Stable-Baselines-Team/stable-baselines3-contrib
#
# Repositorio de RL Baselines3 zoo: https://github.com/DLR-RM/rl-baselines3-zoo
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) es un marco de entrenamiento para problemas de Aprendizaje por Refuerzo (RL) utilizando Stable-Baselines3. Este proporciona scripts para realizar el entrenamiento, evaluación de agentes, ajuste de hiperparámetros, gráfica de resultados y grabación de videos.
#
# ## Introducción
#
# A continuación describimos los elementos necesarios para utilizar la librería stable_basleines: cómo crear un modelo de RL, entrenarlo y evaluarlo. Debido a que todos los algoritmos comparten la misma interfaz, veremos qué es muy simple cambiar entre algoritmos.
#
# ## Instalar Depedencias y Stable-Baselines3 usando pip
#
# La lista completa de dependencias puede ser encontrada en el archivo [README](https://github.com/DLR-RM/stable-baselines3) del repositorio oficial.
#
# Tengan encuenta que algunas dependencias de StableBaselines únicamente son compatibles con versiones de Python entre 3.8 y 3.11, es posible que tengan que instalar la versión 3.10 de Python para correrlo `conda create -n py310 python=3.10`.
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# !apt-get install ffmpeg freeglut3-dev xvfb  # Para visualización
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# zsh:1: command not found: apt-get
# Requirement already satisfied: stable-baselines3>=2.0.0a4 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.8.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.2.6)
# Requirement already satisfied: torch<3.0,>=2.3 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.11.0)
# Requirement already satisfied: cloudpickle in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: pandas in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.3.3)
# Requirement already satisfied: matplotlib in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.10.8)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.0.4)
# Requirement already satisfied: filelock in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.25.2)
# Requirement already satisfied: setuptools<82 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2026.3.0)
# Requirement already satisfied: opencv-python in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.13.0.92)
# Requirement already satisfied: pygame-ce in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.5.7)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (2.20.0)
# Requirement already satisfied: psutil in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (7.0.0)
# Requirement already satisfied: tqdm in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (4.67.3)
# Requirement already satisfied: rich in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (14.3.3)
# Requirement already satisfied: ale-py>=0.9.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (0.11.2)
# Requirement already satisfied: pillow in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a4) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.80.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.10.2)
# Requirement already satisfied: packaging in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (26.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (7.34.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from pandas->stable-baselines3>=2.0.0a4->stable-baselines3[extra]>=2.0.0a4) (2026.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)

# %% [markdown]
# ## Imports
#
# Stable-Baselines3 funciona en ambientes que siguen la [interfaz y estructura de Gym](https://stable-baselines3.readthedocs.io/en/master/guide/custom_env.html).
# Puede encontrar una lista de ambientes disponibles [aquí](https://gymnasium.farama.org/environments/classic_control/).
#
# No todos los algoritmos funcionan con todos los espacios de acciones definidos; puede encontrar más información en [esta tabla](https://stable-baselines3.readthedocs.io/en/master/guide/algos.html)

# %%
import gymnasium as gym #SB3 trabaja con ambientes de gymnasium
import numpy as np

# %% [markdown]
# Lo primero que necesitamos hacer es importar el modelo de RL. Puede revisar la documentación para saber qué modelo se puede utilizar para cada problema. En este tutorial se utilizará el algoritmo de `PPO`.

# %%
from stable_baselines3 import PPO #Se importa el algoritmo PPO de SB3

# %% [markdown]
# El siguiente paso es importar la clase de la política que será utilizada para crear las redes neuronales (para la política/funciones de valor). Este paso en realidad es opcional, ya que se pueden usar strings directamente en los constructores. Por ejemplo:
#
# ```PPO('MlpPolicy', env)``` en lugar de ```PPO(MlpPolicy, env)```
#
# Note también que algunos algoritmos como `SAC` tienen su propia `MlpPolicy`, y es por eso que utilizar los strings para la política es la opción recomendada.

# %%
from stable_baselines3.ppo.policies import MlpPolicy

# %% [markdown]
# ## Crea el ambiente de Gym e instancia el agente
#
# Para este ejemplo, utilizaremos el ambiente de CartPole, un problema muy popular de control.
#
# "Un poste es unido mediante una junta sin actuadores a un carro, el cual se mueve por una superficie sin fricción. El sistema se controla aplicando una fuerza de +1 o -1 al carro. El poste comienza en posición erguida hacia arriba, y el objetivo es prevenir que caiga. Se recibe una recompensa de +1 por cada paso de tiempo que el poste permanece hacia arriba."
#
# Cartpole environment: [https://gymnasium.farama.org/environments/classic_control/cart_pole/](https://gymnasium.farama.org/environments/classic_control/cart_pole/)
#
# ![Cartpole](https://cdn-images-1.medium.com/max/1143/1*h4WTQNVIsvMXJTCpXm_TAw.gif)
#
#
# Para este caso escogemos la MlpPolicy porque el espacio de observación del CartPole es un vector de características, no imágenes.
#
# El tipo de acción que se usa (discreta/continua) será deducido de forma automática a partir del espacio de acciones del ambiente.
#
# Aquí usaremos el algoritmo de [Proximal Policy Optimization](https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html), el cual es un método Actor-Crítico: usa una función de valor para mejorar el descenso de gradiente de la política (reduciendo la varianza). Este algoritmo combina las ideas de [A2C](https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html) (disponiendo de múltiples trabajadores que usan bonos de entropía para fomentar la exploración) y [TRPO](https://stable-baselines.readthedocs.io/en/master/modules/trpo.html) (usa una región de confianza para mejorar la estabilidad y evitar caídas catastróficas de rendimiento).
#
# PPO es un algoritmo on-policy, lo cual significa que las trayectorias utilizadas para actualizar las redes neuronales deben ser recolectadas utilizando la última política actualizada. Es en realidad menos eficiente en términos de muestras que los algoritmos off-policy como [DQN](https://stable-baselines.readthedocs.io/en/master/modules/dqn.html), [SAC](https://stable-baselines3.readthedocs.io/en/master/modules/sac.html) o [TD3](https://stable-baselines3.readthedocs.io/en/master/modules/td3.html), pero es mucho más rápido en términos reales de tiempo.

# %%
env = gym.make("CartPole-v1") #Se crea el ambiente

model = PPO(MlpPolicy, env, verbose=0) #Se instancia el algoritmo
#model = PPO('MlpPolicy', env, verbose=0) #Alternativa recomendada

# %% [markdown]
# Creamos una función adicional para evaluar el agente:

# %%
from stable_baselines3.common.base_class import BaseAlgorithm

def evaluate(
    model: BaseAlgorithm,
    num_episodes: int = 100,
    deterministic: bool = True,
) -> float:
    """
    Evalua un agente de RL por 'num_episodes' episodios.

    Lista de parámetros
    :model: el agente de RL
    :env: el ambiente de Gym
    :num_episodes: número de episodios para evaluar el agente (100 por defecto)
    :deterministic: si utilizar acciones determinísticas o estocásticas (True por defecto

    :return: recompensa promedio en los `num_episodes` episodios (float)
    """
    # Esta función funciona para un único ambiente
    vec_env = model.get_env()
    obs = vec_env.reset() #reinicia el ambiente
    all_episode_rewards = [] #lista vacía para almacenar recompensas
    for _ in range(num_episodes): #ciclo de num_episodes episodios
        episode_rewards = [] #almacena las recompensas del episodio
        done = False #inicializa condición de terminación

        # Nota: SB3 VecEnv se reinicia automáticamente:
        # https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecenv-api-vs-gym-api
        # obs = vec_env.reset()

        while not done: #ejecuta un episodio
            # _states son sólo útiles cuando se usan políticas LSTM
            # `deterministic` es para usar acciones determinísticas
            action, _states = model.predict(obs, deterministic=deterministic) #el modelo predice qué acción elegir en base al pultimo estado observado
            # en este caso action, rewards y dones son arreglos
            # porque se está usando un ambiente vectorizado
            obs, reward, done, _info = vec_env.step(action) #da el paso y observa el nuevo estado y recompensa
            episode_rewards.append(reward) #almacena recompensa

        all_episode_rewards.append(sum(episode_rewards)) #calcula el retorno del episodio (suma) y lo almacena en la lista

    mean_episode_reward = np.mean(all_episode_rewards) #calcula la recompensa promedio
    print(f"Mean reward: {mean_episode_reward:.2f} - Num episodes: {num_episodes}") #da un print con la recompensa promedio

    return mean_episode_reward #retorna la recompensa promedio

# %% [markdown]
# Evaluemos un agente sin entrenar, este debería ser un agente aleatorio.

# %%
# Agente aleatorio, antes del entrenamiento
mean_reward_before_train = evaluate(model, num_episodes=100, deterministic=True)
# Out:
# Mean reward: 9.44 - Num episodes: 100

# %% [markdown]
# No obstante, Stable-Baselines3 ya tiene incluida una función similar para evaluar agentes:

# %%
from stable_baselines3.common.evaluation import evaluate_policy #importa la función evaluate_policy para evaluar agentes directamente

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100, warn=False) #obtiene la recompensa promedio y desviación estándar

print(f"mean_reward: {mean_reward:.2f} +/- {std_reward:.2f}") #imprime resultados
# Out:
# mean_reward: 9.59 +/- 0.74

# %% [markdown]
# ## Entrenar y evaluar el agente

# %%
# Entrena el agent por 10000 pasos
model.learn(total_timesteps=10_000) #usa model.learn para entrenar el agent

# %%
# Evalúa el agente entrenado
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100) #obtiene la recompensa promedio y desviación estándar

print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}") #imprime resultados
# Out:
# /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:273.91 +/- 107.83

# %% [markdown]
# ¡Aparentemente el entrenamiento funcionó porque la recompensa incrementó mucho!

# %% [markdown]
# ### Preparar grabación de video
#
# En este tutorial se muestra la forma de grabar un video utilizando el wrapper [VecVideoRecorder](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecvideorecorder) wrapper. Se realiza una explicación sobre qué son los wrappers y cómo funcionan en [este segundo tutorial](https://github.com/araffin/rl-tutorial-jnrr19/blob/sb3/2_gym_wrappers_saving_loading.ipynb).

# %%
# Hay que configurar fake display; de lo contrario el redner fallará
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

import base64
from pathlib import Path

from IPython import display as ipythondisplay


def show_videos(video_path="", prefix=""):
    """
    Tomado de https://github.com/eleurent/highway-env

    Lista de parámetros
    :video_path: (str)Ruta a la carpeta que contiene los videos
    :prefix: (str) Filtra el video, mostrando sólo los que inician con este prefijo
    """
    html = []
    for mp4 in Path(video_path).glob("{}*.mp4".format(prefix)):
        video_b64 = base64.b64encode(mp4.read_bytes())
        html.append(
            """<video alt="{}" autoplay
                    loop controls style="height: 400px;">
                    <source src="data:video/mp4;base64,{}" type="video/mp4" />
                </video>""".format(
                mp4, video_b64.decode("ascii")
            )
        )
    ipythondisplay.display(ipythondisplay.HTML(data="<br>".join(html)))


from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

def record_video(env_id, model, video_length=500, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: gym.make(env_id, render_mode="rgb_array")])
    # Comienza el video en step=0 y graba 500 pasos
    eval_env = VecVideoRecorder(
        eval_env,
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )

    obs = eval_env.reset()
    for _ in range(video_length):
        action, _ = model.predict(obs)
        obs, _, _, _ = eval_env.step(action)

    # Cierra la grabadora de video
    eval_env.close()

# %% [markdown]
# # Visualiza el agente entrenado

# %%
record_video("CartPole-v1", model, video_length=500, prefix="ppo-cartpole") #graba el video
# Out:
# objc[84194]: Class SDL_RumbleMotor is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcd40) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807c9c8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_RumbleContext is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcd90) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807ca18). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLApplication is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbc890) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807ca68). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLAppDelegate is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbc8e0) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cab8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLTranslatorResponder is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbc958) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cb30). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLMessageBoxPresenter is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbc980) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cb58). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_cocoametalview is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbc9d0) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cba8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLOpenGLContext is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbca20) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cbf8). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_ShapeData is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbca98) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cc70). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_CocoaClosure is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcae8) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807ccc0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_VideoData is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcb38) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cd10). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDL_WindowData is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcb88) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cd60). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLWindow is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcbb0) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cd88). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class Cocoa_WindowListener is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcbd8) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cdb0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class SDLView is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcc50) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807ce28). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class METAL_RenderData is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbccc8) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cea0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# objc[84194]: Class METAL_TextureData is implemented in both /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/cv2/.dylibs/libSDL2-2.0.0.dylib (0x16fdbcd18) and /Users/NicolasCardozo/miniconda3/envs/py310/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x32807cef0). This may cause spurious casting failures and mysterious crashes. One of the duplicates must be removed or renamed.
# Saving video to /Users/NicolasCardozo/Documents/workspace-all/RL/course/isis4222-rl/week10/videos/ppo-cartpole-step-0-to-step-500.mp4
# MoviePy - Building video /Users/NicolasCardozo/Documents/workspace-all/RL/course/isis4222-rl/week10/videos/ppo-cartpole-step-0-to-step-500.mp4.
# MoviePy - Writing video /Users/NicolasCardozo/Documents/workspace-all/RL/course/isis4222-rl/week10/videos/ppo-cartpole-step-0-to-step-500.mp4
# MoviePy - Done !
# MoviePy - video ready /Users/NicolasCardozo/Documents/workspace-all/RL/course/isis4222-rl/week10/videos/ppo-cartpole-step-0-to-step-500.mp4

# %%
show_videos("videos", prefix="ppo") #muestra el video
# Out:
# <video alt="videos/ppo-cartpole-step-0-to-step-500.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>

# %% [markdown]
# ## EXTRA: Entrena un modelo de RL en una sóla línea
#
# La clase de política a usar será inferida y el ambiente será automáticamente creado. Esto funciona porque ambos se encuentran [registrados](https://stable-baselines3.readthedocs.io/en/master/guide/quickstart.html).

# %%
# Entrena un modelo en una sola línea de código
model = PPO('MlpPolicy', "CartPole-v1", verbose=1).learn(10_000)

# %% [markdown]
# # Conclusión
#
# En este notebook hemos aprendido:
# - Cómo definir y entrenar un modelo de RL utilizando stable_baselines3, sólo se necesita una línea de código ;)
